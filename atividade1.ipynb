# %%
import control
import matplotlib.pyplot as plt

# %% [markdown]
# # Questão 1 (Motor CC controlado pelo campo)

# %%
V = 1
J = 2
b = 0.5
La =1e-3
Ra = .4
Kb = 0.0274
Kt = 0.0274
Km = 10
Td =0
Va =1

# %%
modelo_eletrico = control.TransferFunction(1, [La, Ra])
modelo_mecanico = control.TransferFunction(1, [J, b])
modelo_velocidade = control.TransferFunction(1, [1, 0])

# %%
t, y = control.step_response(control.feedback(modelo_eletrico, modelo_mecanico, 1), T_num=10000)

# %%
plt.plot(t, y)
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade (rad/s)')
plt.title('Resposta ao degrau do motor DC')
plt.show()

# %%
modelo_mecanico * modelo_eletrico
# Out:
# TransferFunction(array([1.]), array([0.002 , 0.8005, 0.2   ]))

# %%
t, y = control.step_response(modelo_mecanico * modelo_eletrico)
plt.plot(t, y)
plt.xlabel('Tempo (s)')
plt.ylabel('Velocidade (rad/s)')
plt.title('Resposta ao degrau do motor DC')
plt.show()
